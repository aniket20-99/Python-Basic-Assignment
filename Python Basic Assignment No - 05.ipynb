# %% [markdown]
# ### 1. What does an empty dictionary's code look like?

# %% [markdown]
# **Ans:-** An empty dictionary is represented by two empty curly bracktes like d = {} or d = dict()

# %%
d = {}

d  = dict()

# %% [markdown]
# ### 2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %% [markdown]
# **Ans:-** The value of a dictionary value with the key 'foo' and the value 42, will be written as dict1 = {'foo':42}. In dictionary key and value are seperated by colon within the curly bracket.

# %%
dict1 = {'foo':42}

print(dict1)
# Out:
# {'foo': 42}

# %% [markdown]
# ### 3. What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# **Ans:-** **Dictionary:** Dictionaries are represented by {},The Items stored in a dictionary are Unordered.
#
# **List:** Where as listed are represented by []. while the items in a list are ordered

# %% [markdown]
# ###  4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %%
spam = {'bar':100} 

spam['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 spam = {'bar':100}
# ----> 3 spam['foo']
#
# KeyError: 'foo'

# %% [markdown]
# **Ans:-** If we try to access spam['foo'] if spam is {'bar': 100}, it will give KeyError: 'foo'

# %% [markdown]
# ### 5. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and 'cat' in spam.keys()?

# %% [markdown]
# **Ans:-** There is no difference . The operator checks whether a value exits as a key in the dictionary or not

# %% [markdown]
# ### 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

# %% [markdown]
# **Ans:-** 'cat' in spam checks whether there is a 'cat' key in the dictionary, while 'cat' in spam.values() checks whether there is a value 'cat' for one of the keys in spam.

# %% [markdown]
# ### 7. What is a shortcut for the following code?
#
# if 'color' not in spam:
#
# spam['color'] = 'black'

# %% [markdown]
# **Ans:-** spam.setdefault('color','black')

# %%
spam.setdefault('color','black')
# Out:
# 'black'

# %% [markdown]
# ### 8. How do you "pretty print" dictionary values using which module and function?

# %% [markdown]
# **Ans:-** To "pretty print" dictionary values in Python, you can make use of the pprint module and its pprint() function.

# %%
import pprint

my_dict = {'john': 23, 'Jason': 25, 'Jackson': 30}

pprint.pprint(my_dict)
# Out:
# {'Jackson': 30, 'Jason': 25, 'john': 23}
